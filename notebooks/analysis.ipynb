# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("TrafficWeatherAccidents") \
    .getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://68612dd9f46b:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>TrafficWeatherAccidents</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import pandas as pd
from pathlib import Path

data_dir = Path("..") / "data"

acc_excel_path = data_dir / "OPENDATA_MAP_2017-2024.xlsx"
weather_excel_path = data_dir / "synop_data.xls"

acc_csv_path = data_dir / "accidents.csv"
weather_csv_path = data_dir / "weather.csv"

df_acc = pd.read_excel(acc_excel_path)
df_acc.to_csv(acc_csv_path, index=False)

df_weather = pd.read_excel(weather_excel_path)
df_weather.to_csv(weather_csv_path, index=False)

# %%
accidents_path = "/home/jovyan/work/data/accidents.csv"
traffic_path = "/home/jovyan/work/data/traffic_live_geom.csv"
weather_path = "/home/jovyan/work/data/weather.csv"

accidents_df = spark.read.option("header", "true").option("inferSchema", "true").csv(accidents_path)
traffic_df   = spark.read.option("header", "true").option("inferSchema", "true").csv(traffic_path)
weather_df   = spark.read.option("header", "true").option("inferSchema", "true").csv(weather_path)

accidents_df.printSchema()
traffic_df.printSchema()
weather_df.printSchema()
# Out:
# root
#  |-- DT_YEAR_COLLISION: integer (nullable = true)
#  |-- DT_MONTH_COLLISION: integer (nullable = true)
#  |-- DT_TIME: integer (nullable = true)
#  |-- CD_NIS: integer (nullable = true)
#  |-- TX_RGN_COLLISION_FR: string (nullable = true)
#  |-- TX_RGN_COLLISION_NL: string (nullable = true)
#  |-- TX_PROV_COLLISION_FR: string (nullable = true)
#  |-- TX_PROV_COLLISION_NL: string (nullable = true)
#  |-- TX_MUNTY_COLLISION_FR: string (nullable = true)
#  |-- TX_MUNTY_COLLISION_NL: string (nullable = true)
#  |-- MS_X_COORD: double (nullable = true)
#  |-- MS_Y_COORD: double (nullable = true)
#  |-- CD_CROSSWAY: integer (nullable = true)
#  |-- TX_CROSSWAY_FR: string (nullable = true)
#  |-- TX_CROSSWAY_NL: string (nullable = true)
#  |-- CD_WEATHER: string (nullable = true)
#  |-- TX_WEATHER_FR: string (nullable = true)
#  |-- TX_WEATHER_NL: string (nullable = true)
#  |-- CD_ROAD_CONDITION: string (nullable = true)
#  |-- TX_ROAD_CONDITION_FR: string (nullable = true)
#  |-- TX_ROAD_CONDITION_NL: string (nullable = true)
#  |-- CD_BUILD_UP_AREA: integer (nullable = true)
#  |-- TX_BUILD_UP_AREA_FR: string (nullable = true)
#  |-- TX_BUILD_UP_AREA_NL: string (nullable = true)
#  |-- CD_LIGHT_CONDITION: integer (nullable = true)
#  |-- TX_LIGHT_CONDITION_FR: string (nullable = true)
#  |-- TX_LIGHT_CONDITION_NL: string (nullable = true)
#  |-- CD_ROAD_TYPE: integer (nullable = true)
#  |-- CD_ROAD_TYPE_FR: string (nullable = true)
#  |-- CD_ROAD_TYPE_NL: string (nullable = true)
#  |-- CD_CLASS_ACCIDENTS: integer (nullable = true)
#  |-- TX_CLASS_ACCIDENTS_FR: string (nullable = true)
#  |-- TX_CLASS_ACCIDENTS_NL: string (nullable = true)
#  |-- CD_ROAD_USR_TYPE1: integer (nullable = true)
#  |-- TX_ROAD_USR_TYPE1_FR: string (nullable = true)
#  |-- TX_ROAD_USR_TYPE1_NL: string (nullable = true)
#  |-- CD_ROAD_USR_TYPE2: integer (nullable = true)
#  |-- TX_ROAD_USR_TYPE2_FR: string (nullable = true)
#  |-- TX_ROAD_USR_TYPE2_NL: string (nullable = true)
#  |-- CD_COLLISION_TYPE: string (nullable = true)
#  |-- TX_COLLISON_TYPE_FR: string (nullable = true)
#  |-- TX_COLLISION_TYPE_NL: string (nullable = true)
#  |-- CD_OBSTACLES: integer (nullable = true)
#  |-- TX_OBSTACLES_FR: string (nullable = true)
#  |-- TX_OBSTACLES_NL: string (nullable = true)
#
# root
#  |-- FID: string (nullable = true)
#  |-- id: integer (nullable = true)
#  |-- geom: string (nullable = true)
#  |-- traverse_name: string (nullable = true)
#  |-- descr_fr: string (nullable = true)
#  |-- descr_nl: string (nullable = true)
#  |-- descr_en: string (nullable = true)
#  |-- num_lanes: integer (nullable = true)
#  |-- orientation: integer (nullable = true)
#  |-- url: string (nullable = true)
#  |-- is_active: integer (nullable = true)
#  |-- count_1m_a: integer (nullable = true)
#  |-- speed_1m_a: double (nullable = true)
#  |-- occupancy_1m_a: double (nullable = true)
#  |-- start_time_1m_a: timestamp (nullable = true)
#  |-- end_time_1m_a: timestamp (nullable = true)
#  |-- count_1m_b: integer (nullable = true)
#  |-- speed_1m_b: double (nullable = true)
#  |-- occupancy_1m_b: double (nullable = true)
#  |-- start_time_1m_b: timestamp (nullable = true)
#  |-- end_time_1m_b: timestamp (nullable = true)
#  |-- count_5m_a: integer (nullable = true)
#  |-- speed_5m_a: double (nullable = true)
#  |-- occupancy_5m_a: double (nullable = true)
#  |-- start_time_5m_a: timestamp (nullable = true)
#  |-- end_time_5m_a: timestamp (nullable = true)
#  |-- count_5m_b: integer (nullable = true)
#  |-- speed_5m_b: double (nullable = true)
#  |-- occupancy_5m_b: double (nullable = true)
#  |-- start_time_5m_b: timestamp (nullable = true)
#  |-- end_time_5m_b: timestamp (nullable = true)
#  |-- count_15m_a: integer (nullable = true)
#  |-- speed_15m_a: double (nullable = true)
#  |-- occupancy_15m_a: double (nullable = true)
#  |-- start_time_15m_a: timestamp (nullable = true)
#  |-- end_time_15m_a: timestamp (nullable = true)
#  |-- count_15m_b: integer (nullable = true)
#  |-- speed_15m_b: double (nullable = true)
#  |-- occupancy_15m_b: double (nullable = true)
#  |-- start_time_15m_b: timestamp (nullable = true)
#  |-- end_time_15m_b: timestamp (nullable = true)
#  |-- count_60m_a: integer (nullable = true)
#  |-- speed_60m_a: double (nullable = true)
#  |-- occupancy_60m_a: double (nullable = true)
#  |-- start_time_60m_a: timestamp (nullable = true)
#  |-- end_time_60m_a: timestamp (nullable = true)
#  |-- count_60m_b: integer (nullable = true)
#  |-- speed_60m_b: double (nullable = true)
#  |-- occupancy_60m_b: double (nullable = true)
#  |-- start_time_60m_b: timestamp (nullable = true)
#  |-- end_time_60m_b: timestamp (nullable = true)
#
# root
#  |-- FID: string (nullable = true)
#  |-- the_geom: string (nullable = true)
#  |-- code: integer (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- precip_quantity: string (nullable = true)
#  |-- precip_range: string (nullable = true)
#  |-- temp: double (nullable = true)
#  |-- temp_min: string (nullable = true)
#  |-- temp_max: string (nullable = true)
#  |-- temp_grass_min: string (nullable = true)
#  |-- wind_speed: double (nullable = true)
#  |-- wind_speed_unit: integer (nullable = true)
#  |-- wind_direction: double (nullable = true)
#  |-- wind_peak_speed: double (nullable = true)
#  |-- humidity_relative: double (nullable = true)
#  |-- weather_current: double (nullable = true)
#  |-- pressure: double (nullable = true)
#  |-- pressure_station_level: double (nullable = true)
#  |-- sun_duration_24hours: string (nullable = true)
#  |-- short_wave_from_sky_24hours: string (nullable = true)
#  |-- cloudiness: double (nullable = true)
